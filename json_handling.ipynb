# %%
import json

# Define the data
data = {
    "books": [
        {
            "title": "One Hundred Years of Solitude",
            "author": "Gabriel Garcia Marquez",
            "reviews": [
                {
                    "reviewer": {
                        "name": "Kanwal Mehreen",
                        "location": "Islamabad, Pakistan"
                    },
                    "rating": 4.5,
                    "comments": "Magical and completely breathtaking!"
                },
                {
                    "reviewer": {
                        "name": "Isabella Martinez",
                        "location": "Bogotá, Colombia"
                    },
                    "rating": 4.7,
                    "comments": "A marvelous journey through a world of magic."
                }
            ]
        },
        {
            "title": "Things Fall Apart",
            "author": "Chinua Achebe",
            "reviews": [
                {
                    "reviewer": {
                        "name": "Zara Khan",
                        "location": "Lagos, Nigeria"
                    },
                    "rating": 4.9,
                    "comments": "Things Fall Apart is the best of contemporary African literature."
                }
            ]
        }
    ]
}

# Write the data to a JSON file
with open('books.json', 'w') as json_file:
    json.dump(data, json_file, indent=4)

print("Data has been written to books.json")
# Out:
# Data has been written to books.json

# %% [markdown]
# ### Method 1: Using the json.load() and pd.DataFrame() functions

# %%
import json
import pandas as pd

#Load the JSON data

with open('books.json','r') as f:
    data = json.load(f)

#Create a DataFrame from the JSON data

df = pd.DataFrame(data['books'])

df
# Out:
#                            title                  author  \
# 0  One Hundred Years of Solitude  Gabriel Garcia Marquez
# 1              Things Fall Apart           Chinua Achebe
#
#                                              reviews
# 0  [{'reviewer': {'name': 'Kanwal Mehreen', 'loca...
# 1  [{'reviewer': {'name': 'Zara Khan', 'location'...

# %%
#Create a DataFrame from the nested JSON data

df = pd.DataFrame([
{
'title': book['title'],
'author': book['author'],
'reviewer_name': review['reviewer']['name'],
'reviewer_location': review['reviewer']['location'],
'rating': review['rating'],
'comments': review['comments']
}
for book in data['books']
for review in book['reviews']
])

# %%
df
# Out:
#                            title                  author      reviewer_name  \
# 0  One Hundred Years of Solitude  Gabriel Garcia Marquez     Kanwal Mehreen
# 1  One Hundred Years of Solitude  Gabriel Garcia Marquez  Isabella Martinez
# 2              Things Fall Apart           Chinua Achebe          Zara Khan
#
#      reviewer_location  rating  \
# 0  Islamabad, Pakistan     4.5
# 1     Bogotá, Colombia     4.7
# 2       Lagos, Nigeria     4.9
#
#                                             comments
# 0               Magical and completely breathtaking!
# 1      A marvelous journey through a world of magic.
# 2  Things Fall Apart is the best of contemporary ...

# %% [markdown]
# ### Method 2 (Recommended): Using the json_normalize() function

# %%
import pandas as pd
import json

#Load the JSON data

with open('books.json', 'r') as f:
    data = json.load(f)

#Create the DataFrame using json_normalize()

df = pd.json_normalize(
data=data['books'],
meta=['title', 'author'],
record_path='reviews',
errors='raise'
)

df
# Out:
#    rating                                           comments  \
# 0     4.5               Magical and completely breathtaking!
# 1     4.7      A marvelous journey through a world of magic.
# 2     4.9  Things Fall Apart is the best of contemporary ...
#
#        reviewer.name    reviewer.location                          title  \
# 0     Kanwal Mehreen  Islamabad, Pakistan  One Hundred Years of Solitude
# 1  Isabella Martinez     Bogotá, Colombia  One Hundred Years of Solitude
# 2          Zara Khan       Lagos, Nigeria              Things Fall Apart
#
#                    author
# 0  Gabriel Garcia Marquez
# 1  Gabriel Garcia Marquez
# 2           Chinua Achebe
